# %%
import pandas as pd
import pickle
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

# %%
data = pd.read_excel(r"C:\Users\AnTong\Downloads\2023-2024.xlsx")

# %%
data
# Out:
#      HSA  A00_2024  A01_2024  B00_2024  C00_2024  2024_D01
# 0    129     29.35     29.40     29.10     29.75     28.70
# 1    128     29.26     28.99     28.94     29.75     28.55
# 2    127     29.16     28.96     28.90     29.75     28.55
# 3    126     29.14     28.92     28.85     29.75     28.50
# 4    125     29.11     28.80     28.85     29.75     28.50
# ..   ...       ...       ...       ...       ...       ...
# 96    33     10.75     10.94     11.52     14.50     12.98
# 97    32     10.10     10.23     11.34     14.11     12.18
# 98    31     10.04      9.94     11.17     14.02     11.88
# 99    30     10.04      9.94     11.17     14.02     11.88
# 100   29      9.98      9.91     10.94     13.86     11.40
#
# [101 rows x 6 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 101 entries, 0 to 100
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   HSA       101 non-null    int64
#  1   A00_2024  101 non-null    float64
#  2   A01_2024  101 non-null    float64
#  3   B00_2024  101 non-null    float64
#  4   C00_2024  101 non-null    float64
#  5   2024_D01  101 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 4.9 KB

# %%
df1 = data[['HSA', "2024_D01"]]

# %%
X = df1['HSA'].values.reshape(-1, 1)
y = df1['2024_D01'].values
# Create a pipeline with StandardScaler and LinearRegression
lr = LinearRegression()
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
with open(f'model_D01.pkl', 'wb') as f:
    pickle.dump(lr, f)
